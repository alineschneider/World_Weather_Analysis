# %%
# Import the dependencies.
import pandas as pd
from citipy import citipy
import gmaps
import requests
import numpy as np
from datetime import datetime
# Import the API key.
from config import g_key
from config import weather_api_key
import traceback

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Get the amount of rainfall in inches for the last three hours
        try:
            if "3h" in city_weather["rain"]:
                city_rain = city_weather["rain"]["3h"]
            else:
                city_rain = 0
        except KeyError:
            city_rain = 0
        # Get the amount of snowfall in inches for the last three hours
        try:
            if "3h" in city_weather["snow"]:
                city_snow = city_weather["snow"]["3h"]
            else:
                city_snow = 0
        except KeyError:
            city_snow = 0
            
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain inches (last 3hrs)": city_rain,
                          "Snow inches (last 3hrs)": city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | winslow
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | uthal
# Processing Record 7 of Set 1 | raudeberg
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | caravelas
# Processing Record 11 of Set 1 | de-kastri
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | faya
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | pimentel
# Processing Record 22 of Set 1 | tezu
# Processing Record 23 of Set 1 | zaykovo
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | puerto del rosario
# Processing Record 26 of Set 1 | kyabe
# Processing Record 27 of Set 1 | kohima
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | leh
# Processing Record 31 of Set 1 | los llanos de aridane
# Processing Record 32 of Set 1 | mason city
# Processing Record 33 of Set 1 | shelburne
# Processing Record 34 of Set 1 | salalah
# Processing Record 35 of Set 1 | warri
# Processing Record 36 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | kupang
# Processing Record 40 of Set 1 | vila velha
# Processing Record 41 of Set 1 | torres
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | henties bay
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | hami
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | lavrentiya
# Processing Record 48 of Set 1 | lorengau
# Processing Record 49 of Set 1 | kadnikov
# Processing Record 50 of Set 1 | zhirnov
# Processing Record 1 of Set 2 | narsaq
# Processing Record 2 of Set 2 | wanning
# Processing Record 3 of Set 2 | tiarei
# Processing Record 4 of Set 2 | antofagasta
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | barcelos
# Processing Record 9 of Set 2 | katsuura
# Processing Record 10 of Set 2 | altonia
# City not found. Skipping...
# Processing Record 11 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | madang
# Processing Record 17 of Set 2 | yatou
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | san carlos de bariloche
# Processing Record 22 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 2 | santa rosa
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 2 | mayo
# Processing Record 27 of Set 2 | lima
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | muswellbrook
# Processing Record 30 of Set 2 | baisha
# Processing Record 31 of Set 2 | port macquarie
# Processing Record 32 of Set 2 | baker city
# Processing Record 33 of Set 2 | miedzychod
# Processing Record 34 of Set 2 | ocos
# Processing Record 35 of Set 2 | luena
# Processing Record 36 of Set 2 | saint anthony
# Processing Record 37 of Set 2 | altay
# Processing Record 38 of Set 2 | grand gaube
# Processing Record 39 of Set 2 | ambon
# Processing Record 40 of Set 2 | belyy yar
# Processing Record 41 of Set 2 | natal
# Processing Record 42 of Set 2 | beringovskiy
# Processing Record 43 of Set 2 | marawi
# Processing Record 44 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | sangar
# Processing Record 1 of Set 3 | walvis bay
# Processing Record 2 of Set 3 | landau
# Processing Record 3 of Set 3 | tarakan
# Processing Record 4 of Set 3 | japura
# Processing Record 5 of Set 3 | vao
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | goderich
# Processing Record 8 of Set 3 | avera
# Processing Record 9 of Set 3 | dhidhdhoo
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | algiers
# Processing Record 12 of Set 3 | corridonia
# Processing Record 13 of Set 3 | isla mujeres
# Processing Record 14 of Set 3 | pecos
# Processing Record 15 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 3 | catuday
# Processing Record 17 of Set 3 | bahia blanca
# Processing Record 18 of Set 3 | tiznit
# Processing Record 19 of Set 3 | decatur
# Processing Record 20 of Set 3 | laguna
# Processing Record 21 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | casselman
# Processing Record 26 of Set 3 | wanaka
# Processing Record 27 of Set 3 | omsukchan
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | shestakovo
# Processing Record 30 of Set 3 | bridlington
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | umtata
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | riyadh
# Processing Record 38 of Set 3 | gorom-gorom
# Processing Record 39 of Set 3 | hobyo
# Processing Record 40 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | cortez
# Processing Record 43 of Set 3 | kyra
# Processing Record 44 of Set 3 | collie
# Processing Record 45 of Set 3 | tuatapere
# Processing Record 46 of Set 3 | necochea
# Processing Record 47 of Set 3 | luoyang
# Processing Record 48 of Set 3 | mao
# Processing Record 49 of Set 3 | tautira
# Processing Record 50 of Set 3 | jalu
# Processing Record 1 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 4 | sitka
# Processing Record 3 of Set 4 | abha
# Processing Record 4 of Set 4 | kaohsiung
# Processing Record 5 of Set 4 | karratha
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | ballina
# Processing Record 8 of Set 4 | tiksi
# Processing Record 9 of Set 4 | waitati
# Processing Record 10 of Set 4 | ust-kuyga
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | karlivka
# Processing Record 13 of Set 4 | kushima
# Processing Record 14 of Set 4 | polovinnoye
# Processing Record 15 of Set 4 | boyolangu
# Processing Record 16 of Set 4 | pacific grove
# Processing Record 17 of Set 4 | guerrero negro
# Processing Record 18 of Set 4 | mackenzie
# Processing Record 19 of Set 4 | nara
# Processing Record 20 of Set 4 | cockburn town
# Processing Record 21 of Set 4 | bouake
# Processing Record 22 of Set 4 | along
# Processing Record 23 of Set 4 | new norfolk
# Processing Record 24 of Set 4 | pangnirtung
# Processing Record 25 of Set 4 | formosa do rio preto
# Processing Record 26 of Set 4 | hammond
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | manokwari
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | yellowknife
# Processing Record 31 of Set 4 | derzhavinsk
# Processing Record 32 of Set 4 | georgetown
# Processing Record 33 of Set 4 | la ronge
# Processing Record 34 of Set 4 | oranjemund
# Processing Record 35 of Set 4 | cape town
# Processing Record 36 of Set 4 | sabha
# Processing Record 37 of Set 4 | lensk
# Processing Record 38 of Set 4 | marzuq
# Processing Record 39 of Set 4 | melita
# Processing Record 40 of Set 4 | oudtshoorn
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | houma
# Processing Record 43 of Set 4 | westport
# Processing Record 44 of Set 4 | sola
# Processing Record 45 of Set 4 | grindavik
# Processing Record 46 of Set 4 | alford
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | san jose
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | kalmar
# Processing Record 1 of Set 5 | kutum
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | port hardy
# Processing Record 4 of Set 5 | isangel
# Processing Record 5 of Set 5 | sistranda
# Processing Record 6 of Set 5 | lasa
# Processing Record 7 of Set 5 | ust-maya
# Processing Record 8 of Set 5 | chapais
# Processing Record 9 of Set 5 | medford
# Processing Record 10 of Set 5 | benghazi
# Processing Record 11 of Set 5 | coquimbo
# Processing Record 12 of Set 5 | borisoglebsk
# Processing Record 13 of Set 5 | dunedin
# Processing Record 14 of Set 5 | chachapoyas
# Processing Record 15 of Set 5 | kumylzhenskaya
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | lubango
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | changuinola
# Processing Record 20 of Set 5 | belaya gora
# Processing Record 21 of Set 5 | gualeguaychu
# Processing Record 22 of Set 5 | khilok
# Processing Record 23 of Set 5 | victor harbor
# Processing Record 24 of Set 5 | shubarkuduk
# Processing Record 25 of Set 5 | tanout
# Processing Record 26 of Set 5 | parkes
# Processing Record 27 of Set 5 | tessalit
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | porbandar
# Processing Record 30 of Set 5 | lompoc
# Processing Record 31 of Set 5 | fochville
# Processing Record 32 of Set 5 | berdsk
# Processing Record 33 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 34 of Set 5 | nuuk
# Processing Record 35 of Set 5 | mandalgovi
# Processing Record 36 of Set 5 | catamarca
# Processing Record 37 of Set 5 | veraval
# Processing Record 38 of Set 5 | saskylakh
# Processing Record 39 of Set 5 | canavieiras
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | rincon
# Processing Record 43 of Set 5 | kovylkino
# Processing Record 44 of Set 5 | lake charles
# Processing Record 45 of Set 5 | upernavik
# Processing Record 46 of Set 5 | kirovsk
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | kahului
# Processing Record 49 of Set 5 | chumikan
# Processing Record 50 of Set 5 | mildura
# Processing Record 1 of Set 6 | tucurui
# Processing Record 2 of Set 6 | owando
# Processing Record 3 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 6 | duku
# Processing Record 5 of Set 6 | szihalom
# Processing Record 6 of Set 6 | qaanaaq
# Processing Record 7 of Set 6 | victoria
# Processing Record 8 of Set 6 | sibolga
# Processing Record 9 of Set 6 | ribeira brava
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | vestmannaeyjar
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | kavaratti
# Processing Record 14 of Set 6 | barrow
# Processing Record 15 of Set 6 | teknaf
# Processing Record 16 of Set 6 | portland
# Processing Record 17 of Set 6 | hilton head island
# Processing Record 18 of Set 6 | sungurlu
# Processing Record 19 of Set 6 | bowen
# Processing Record 20 of Set 6 | labuhan
# Processing Record 21 of Set 6 | sabang
# Processing Record 22 of Set 6 | puerto ayora
# Processing Record 23 of Set 6 | carballo
# Processing Record 24 of Set 6 | bend
# Processing Record 25 of Set 6 | ulaanbaatar
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | pevek
# Processing Record 28 of Set 6 | husavik
# Processing Record 29 of Set 6 | kungurtug
# Processing Record 30 of Set 6 | bethel
# Processing Record 31 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | kysyl-syr
# Processing Record 34 of Set 6 | port hawkesbury
# Processing Record 35 of Set 6 | colac
# Processing Record 36 of Set 6 | salcedo
# Processing Record 37 of Set 6 | umm kaddadah
# Processing Record 38 of Set 6 | mujiayingzi
# Processing Record 39 of Set 6 | slave lake
# Processing Record 40 of Set 6 | cap malheureux
# Processing Record 41 of Set 6 | puerto narino
# Processing Record 42 of Set 6 | saint-francois
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | pong
# Processing Record 45 of Set 6 | namatanai
# Processing Record 46 of Set 6 | torit
# Processing Record 47 of Set 6 | butaritari
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | half moon bay
# Processing Record 50 of Set 6 | codrington
# Processing Record 1 of Set 7 | eureka
# Processing Record 2 of Set 7 | broome
# Processing Record 3 of Set 7 | san quintin
# Processing Record 4 of Set 7 | kawalu
# Processing Record 5 of Set 7 | gobabis
# Processing Record 6 of Set 7 | ixtapa
# Processing Record 7 of Set 7 | rio grande
# Processing Record 8 of Set 7 | vanimo
# Processing Record 9 of Set 7 | chaibasa
# Processing Record 10 of Set 7 | colchester
# Processing Record 11 of Set 7 | zhuhai
# Processing Record 12 of Set 7 | kencong
# Processing Record 13 of Set 7 | levanger
# Processing Record 14 of Set 7 | celestun
# Processing Record 15 of Set 7 | kudahuvadhoo
# Processing Record 16 of Set 7 | batagay-alyta
# Processing Record 17 of Set 7 | san cristobal
# Processing Record 18 of Set 7 | sydney
# Processing Record 19 of Set 7 | moreira
# Processing Record 20 of Set 7 | temerloh
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | sao filipe
# Processing Record 23 of Set 7 | xingyi
# Processing Record 24 of Set 7 | pathein
# Processing Record 25 of Set 7 | clyde river
# Processing Record 26 of Set 7 | douentza
# Processing Record 27 of Set 7 | orlik
# Processing Record 28 of Set 7 | margate
# Processing Record 29 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 7 | rovaniemi
# Processing Record 31 of Set 7 | gilgit
# Processing Record 32 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 33 of Set 7 | tinjah
# City not found. Skipping...
# Processing Record 34 of Set 7 | ayios vasilios
# Processing Record 35 of Set 7 | aasiaat
# Processing Record 36 of Set 7 | churapcha
# Processing Record 37 of Set 7 | saint-philippe
# Processing Record 38 of Set 7 | saint-joseph
# Processing Record 39 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 40 of Set 7 | bilma
# Processing Record 41 of Set 7 | lazaro cardenas
# Processing Record 42 of Set 7 | port-gentil
# Processing Record 43 of Set 7 | waipawa
# Processing Record 44 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 7 | zinder
# Processing Record 46 of Set 7 | porto santo
# Processing Record 47 of Set 7 | tamale
# Processing Record 48 of Set 7 | kisangani
# Processing Record 49 of Set 7 | melton
# Processing Record 50 of Set 7 | tomislavgrad
# Processing Record 1 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 8 | obeliai
# Processing Record 3 of Set 8 | nadym
# Processing Record 4 of Set 8 | mongu
# Processing Record 5 of Set 8 | khor
# Processing Record 6 of Set 8 | keflavik
# Processing Record 7 of Set 8 | mount gambier
# Processing Record 8 of Set 8 | upata
# Processing Record 9 of Set 8 | tieling
# Processing Record 10 of Set 8 | ajaccio
# Processing Record 11 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 8 | novikovo
# Processing Record 13 of Set 8 | kirakira
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | kroderen
# City not found. Skipping...
# Processing Record 16 of Set 8 | mecca
# Processing Record 17 of Set 8 | havre-saint-pierre
# Processing Record 18 of Set 8 | vardo
# Processing Record 19 of Set 8 | san patricio
# Processing Record 20 of Set 8 | lebu
# Processing Record 21 of Set 8 | homer
# Processing Record 22 of Set 8 | norwich
# Processing Record 23 of Set 8 | berlevag
# Processing Record 24 of Set 8 | east stroudsburg
# Processing Record 25 of Set 8 | miyako
# Processing Record 26 of Set 8 | northam
# Processing Record 27 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 8 | zhigansk
# Processing Record 29 of Set 8 | leshukonskoye
# Processing Record 30 of Set 8 | aberdeen
# Processing Record 31 of Set 8 | mayna
# Processing Record 32 of Set 8 | wahiawa
# Processing Record 33 of Set 8 | rosarito
# Processing Record 34 of Set 8 | pokrovo-prigorodnoye
# Processing Record 35 of Set 8 | norman wells
# Processing Record 36 of Set 8 | sungairaya
# Processing Record 37 of Set 8 | tilichiki
# Processing Record 38 of Set 8 | tignere
# Processing Record 39 of Set 8 | thayetmyo
# Processing Record 40 of Set 8 | batemans bay
# Processing Record 41 of Set 8 | kiunga
# Processing Record 42 of Set 8 | kingston
# Processing Record 43 of Set 8 | claremore
# Processing Record 44 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 8 | bograd
# Processing Record 46 of Set 8 | semey
# Processing Record 47 of Set 8 | concordia
# Processing Record 48 of Set 8 | vostok
# Processing Record 49 of Set 8 | fuling
# Processing Record 50 of Set 8 | gilbues
# Processing Record 1 of Set 9 | ekhabi
# Processing Record 2 of Set 9 | alofi
# Processing Record 3 of Set 9 | ponta do sol
# Processing Record 4 of Set 9 | namuac
# Processing Record 5 of Set 9 | roros
# Processing Record 6 of Set 9 | zhezkazgan
# Processing Record 7 of Set 9 | dakoro
# Processing Record 8 of Set 9 | iqaluit
# Processing Record 9 of Set 9 | cravo norte
# Processing Record 10 of Set 9 | smithers
# Processing Record 11 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 12 of Set 9 | le moule
# Processing Record 13 of Set 9 | aykhal
# Processing Record 14 of Set 9 | tambun
# Processing Record 15 of Set 9 | tapejara
# Processing Record 16 of Set 9 | dwarka
# Processing Record 17 of Set 9 | limbe
# Processing Record 18 of Set 9 | sao raimundo nonato
# Processing Record 19 of Set 9 | ormara
# Processing Record 20 of Set 9 | nacala
# Processing Record 21 of Set 9 | birao
# Processing Record 22 of Set 9 | iquique
# Processing Record 23 of Set 9 | sherman
# Processing Record 24 of Set 9 | tafresh
# Processing Record 25 of Set 9 | davila
# Processing Record 26 of Set 9 | atambua
# Processing Record 27 of Set 9 | marsa matruh
# Processing Record 28 of Set 9 | honiara
# Processing Record 29 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 9 | pisco
# Processing Record 31 of Set 9 | taltal
# Processing Record 32 of Set 9 | rumoi
# Processing Record 33 of Set 9 | opuwo
# Processing Record 34 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 9 | renqiu
# Processing Record 36 of Set 9 | kushalgarh
# Processing Record 37 of Set 9 | sandnessjoen
# Processing Record 38 of Set 9 | bairiki
# Processing Record 39 of Set 9 | camacha
# Processing Record 40 of Set 9 | ahipara
# Processing Record 41 of Set 9 | quatre cocos
# Processing Record 42 of Set 9 | mariental
# Processing Record 43 of Set 9 | coihaique
# Processing Record 44 of Set 9 | sao joao da barra
# Processing Record 45 of Set 9 | paita
# Processing Record 46 of Set 9 | chilac
# City not found. Skipping...
# Processing Record 47 of Set 9 | soyo
# Processing Record 48 of Set 9 | college
# Processing Record 49 of Set 9 | bhuj
# Processing Record 50 of Set 9 | juneau
# Processing Record 1 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 10 | chupei
# City not found. Skipping...
# Processing Record 3 of Set 10 | ridgecrest
# Processing Record 4 of Set 10 | saint-michel-des-saints
# Processing Record 5 of Set 10 | kabinda
# Processing Record 6 of Set 10 | port blair
# Processing Record 7 of Set 10 | jaen
# Processing Record 8 of Set 10 | mountain home
# Processing Record 9 of Set 10 | presidencia roque saenz pena
# Processing Record 10 of Set 10 | ibra
# Processing Record 11 of Set 10 | stony mountain
# Processing Record 12 of Set 10 | ossora
# Processing Record 13 of Set 10 | saint-georges
# Processing Record 14 of Set 10 | okhotsk
# Processing Record 15 of Set 10 | windhoek
# Processing Record 16 of Set 10 | aleksandrov gay
# Processing Record 17 of Set 10 | bonavista
# Processing Record 18 of Set 10 | bathsheba
# Processing Record 19 of Set 10 | bose
# Processing Record 20 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 10 | el balyana
# City not found. Skipping...
# Processing Record 22 of Set 10 | gat
# Processing Record 23 of Set 10 | chicama
# Processing Record 24 of Set 10 | mnogovershinnyy
# Processing Record 25 of Set 10 | sijunjung
# Processing Record 26 of Set 10 | yerbogachen
# Processing Record 27 of Set 10 | melfi
# Processing Record 28 of Set 10 | hirara
# Processing Record 29 of Set 10 | korla
# Processing Record 30 of Set 10 | acajutla
# Processing Record 31 of Set 10 | beloha
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | tura
# Processing Record 34 of Set 10 | beidao
# Processing Record 35 of Set 10 | puerto ayacucho
# Processing Record 36 of Set 10 | flinders
# Processing Record 37 of Set 10 | chardara
# Processing Record 38 of Set 10 | sambava
# Processing Record 39 of Set 10 | salama
# Processing Record 40 of Set 10 | richards bay
# Processing Record 41 of Set 10 | katangli
# Processing Record 42 of Set 10 | buraydah
# Processing Record 43 of Set 10 | paray-le-monial
# Processing Record 44 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 10 | santiago del estero
# Processing Record 46 of Set 10 | angoche
# Processing Record 47 of Set 10 | paoua
# Processing Record 48 of Set 10 | san policarpo
# Processing Record 49 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 50 of Set 10 | nemuro
# Processing Record 1 of Set 11 | atbasar
# Processing Record 2 of Set 11 | asau
# Processing Record 3 of Set 11 | poum
# Processing Record 4 of Set 11 | tungor
# Processing Record 5 of Set 11 | verkh-usugli
# Processing Record 6 of Set 11 | bratsk
# Processing Record 7 of Set 11 | serra branca
# Processing Record 8 of Set 11 | sakaiminato
# Processing Record 9 of Set 11 | ciudad guayana
# Processing Record 10 of Set 11 | awjilah
# Processing Record 11 of Set 11 | pudozh
# Processing Record 12 of Set 11 | arman
# Processing Record 13 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 14 of Set 11 | mihara
# Processing Record 15 of Set 11 | ta khmau
# Processing Record 16 of Set 11 | iracoubo
# Processing Record 17 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 11 | el puerto de santa maria
# Processing Record 19 of Set 11 | pedernales
# Processing Record 20 of Set 11 | nakhon ratchasima
# Processing Record 21 of Set 11 | sokoto
# Processing Record 22 of Set 11 | suclayin
# Processing Record 23 of Set 11 | gezing
# Processing Record 24 of Set 11 | miri
# Processing Record 25 of Set 11 | ostrovnoy
# Processing Record 26 of Set 11 | neuquen
# Processing Record 27 of Set 11 | namibe
# Processing Record 28 of Set 11 | ambilobe
# Processing Record 29 of Set 11 | cayenne
# Processing Record 30 of Set 11 | melilla
# Processing Record 31 of Set 11 | santa catarina de tepehuanes
# Processing Record 32 of Set 11 | aloleng
# Processing Record 33 of Set 11 | khandyga
# Processing Record 34 of Set 11 | mormugao
# Processing Record 35 of Set 11 | bereda
# Processing Record 36 of Set 11 | wewak
# Processing Record 37 of Set 11 | bakel
# Processing Record 38 of Set 11 | kandalaksha
# Processing Record 39 of Set 11 | puerto cortes
# City not found. Skipping...
# Processing Record 40 of Set 11 | kamenka
# Processing Record 41 of Set 11 | bakaly
# Processing Record 42 of Set 11 | chokurdakh
# Processing Record 43 of Set 11 | lac du bonnet
# Processing Record 44 of Set 11 | santa isabel
# Processing Record 45 of Set 11 | wokha
# Processing Record 46 of Set 11 | fershampenuaz
# Processing Record 47 of Set 11 | kedrovyy
# Processing Record 48 of Set 11 | sao desiderio
# Processing Record 49 of Set 11 | eidfjord
# Processing Record 50 of Set 11 | bizhbulyak
# Processing Record 1 of Set 12 | tanuma
# Processing Record 2 of Set 12 | otjiwarongo
# Processing Record 3 of Set 12 | sassandra
# Processing Record 4 of Set 12 | kashi
# Processing Record 5 of Set 12 | eirunepe
# Processing Record 6 of Set 12 | freeport
# Processing Record 7 of Set 12 | caldwell
# Processing Record 8 of Set 12 | orebro
# Processing Record 9 of Set 12 | abbeville
# Processing Record 10 of Set 12 | seidu
# Processing Record 11 of Set 12 | carbonia
# Processing Record 12 of Set 12 | sorland
# Processing Record 13 of Set 12 | lata
# Processing Record 14 of Set 12 | sibu
# Processing Record 15 of Set 12 | shimoda
# Processing Record 16 of Set 12 | ust-karsk
# Processing Record 17 of Set 12 | contesti
# Processing Record 18 of Set 12 | bria
# Processing Record 19 of Set 12 | saurimo
# Processing Record 20 of Set 12 | burrel
# Processing Record 21 of Set 12 | yenagoa
# Processing Record 22 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 23 of Set 12 | saint-leu
# Processing Record 24 of Set 12 | peleduy
# Processing Record 25 of Set 12 | adrar
# Processing Record 26 of Set 12 | mitsamiouli
# Processing Record 27 of Set 12 | mainit
# Processing Record 28 of Set 12 | udachnyy
# Processing Record 29 of Set 12 | kavieng
# Processing Record 30 of Set 12 | talnakh
# Processing Record 31 of Set 12 | cuamba
# Processing Record 32 of Set 12 | aswan
# Processing Record 33 of Set 12 | najran
# Processing Record 34 of Set 12 | kurchum
# Processing Record 35 of Set 12 | tokmak
# Processing Record 36 of Set 12 | santa cruz
# Processing Record 37 of Set 12 | pundaguitan
# Processing Record 38 of Set 12 | dingle
# Processing Record 39 of Set 12 | straumen
# Processing Record 40 of Set 12 | kolokani
# Processing Record 41 of Set 12 | rio gallegos
# Processing Record 42 of Set 12 | te anau
# Processing Record 43 of Set 12 | mpulungu
# Processing Record 44 of Set 12 | yeppoon
# Processing Record 45 of Set 12 | victoria point
# Processing Record 46 of Set 12 | havoysund
# Processing Record 47 of Set 12 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 48 of Set 12 | mount vernon
# Processing Record 49 of Set 12 | novobirilyussy
# Processing Record 50 of Set 12 | marystown
# Processing Record 1 of Set 13 | ouesso
# Processing Record 2 of Set 13 | ewa beach
# Processing Record 3 of Set 13 | ubinskoye
# Processing Record 4 of Set 13 | skala
# Processing Record 5 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 13 | haverfordwest
# Processing Record 7 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 13 | pochutla
# Processing Record 9 of Set 13 | acarau
# Processing Record 10 of Set 13 | abalak
# Processing Record 11 of Set 13 | yining
# Processing Record 12 of Set 13 | valdivia
# Processing Record 13 of Set 13 | kamina
# Processing Record 14 of Set 13 | suntar
# Processing Record 15 of Set 13 | bara
# Processing Record 16 of Set 13 | urumqi
# Processing Record 17 of Set 13 | manggar
# Processing Record 18 of Set 13 | cedar city
# Processing Record 19 of Set 13 | puerto baquerizo moreno
# Processing Record 20 of Set 13 | shangrao
# Processing Record 21 of Set 13 | wuan
# Processing Record 22 of Set 13 | comal
# Processing Record 23 of Set 13 | colesberg
# Processing Record 24 of Set 13 | buenaventura
# Processing Record 25 of Set 13 | thinadhoo
# Processing Record 26 of Set 13 | port lincoln
# Processing Record 27 of Set 13 | mpika
# Processing Record 28 of Set 13 | xihe
# Processing Record 29 of Set 13 | sarangani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0          Winslow      US  2020-04-19 19:49:56  35.02 -110.70     66.20
# 1             Hilo      US  2020-04-19 19:56:18  19.73 -155.09     78.80
# 2      Provideniya      RU  2020-04-19 19:54:23  64.38 -173.30     20.86
# 3             Chuy      UY  2020-04-19 19:57:14 -33.70  -53.46     67.73
# 4            Uthal      PK  2020-04-19 19:59:32  25.81   66.62     77.49
# 5        Raudeberg      NO  2020-04-19 19:59:32  61.99    5.14     46.40
# 6        Busselton      AU  2020-04-19 19:56:17 -33.65  115.33     55.99
# 7  Bambous Virieux      MU  2020-04-19 19:59:33 -20.34   57.76     77.00
# 8        Caravelas      BR  2020-04-19 19:59:33 -17.71  -39.25     76.10
# 9        De-Kastri      RU  2020-04-19 19:59:33  51.47  140.78     34.39
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        15           1       12.91           clear sky
# 1        57          75        3.36       broken clouds
# 2        95         100       15.19          light snow
# 3        78           4        8.21           clear sky
# 4        77          93        2.80     overcast clouds
# 5        70           0        9.17           clear sky
# 6        59          79       17.05       broken clouds
# 7        78          40       10.29    scattered clouds
# 8        76          46       17.65    scattered clouds
# 9        89         100        6.53     overcast clouds
#
#    Rain inches (last 3hrs)  Snow inches (last 3hrs)
# 0                      0.0                     0.00
# 1                      0.0                     0.00
# 2                      0.0                     0.56
# 3                      0.0                     0.00
# 4                      0.0                     0.00
# 5                      0.0                     0.00
# 6                      0.0                     0.00
# 7                      0.0                     0.00
# 8                      0.0                     0.00
# 9                      0.0                     0.00

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
